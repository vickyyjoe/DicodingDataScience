# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - Nama: Vicky Joe
# - Email: vickyyjoe12@gmail.com
# - Id Dicoding: vickyyjoe12

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana perbedaan kualitas udara dilihat dari persepektif tiap bulan di daerah Aotizhongxin selama periode 2013-2017
#
#
# - Jenis Partikel mana yang mengalami perubahan paling banyak selama 2013 - 2017 di daerah Aotizhongxin

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv('PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv')

# %% [markdown]
# mengambil dataset dari drive

# %%
df.head
# Out:
# <bound method NDFrame.head of           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 0      -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1      -1.1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2      -1.1  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3      -1.4  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4      -2.0  1025.2 -19.5   0.0    N   2.0  Aotizhongxin
# ...     ...     ...   ...   ...  ...   ...           ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Aotizhongxin
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Aotizhongxin
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Aotizhongxin
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Aotizhongxin
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Aotizhongxin
#
# [35064 rows x 18 columns]>

# %% [markdown]
# untuk menunjukan data

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ### Cleaning Data

# %%
df = df.dropna()

# %% [markdown]
# untuk menghilangkan data yang null

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# untuk mengecek apahakah ada data yang masi null

# %%
df.loc[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station]
# Index: []

# %% [markdown]
# untuk mengecek data yang duplicate

# %%
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# untuk menujunkan data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   31815.000000  31815.000000  31815.000000  31815.000000  31815.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17899.423857   2014.714914      6.401886     15.578564     11.624800
# std     10058.429849      1.162536      3.416847      8.794954      6.926874
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      9415.500000   2014.000000      3.000000      8.000000      6.000000
# 50%     18093.000000   2015.000000      6.000000     15.000000     12.000000
# 75%     26590.500000   2016.000000      9.000000     23.000000     18.000000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count   31815.00000  31815.000000  31815.000000  31815.000000  31815.000000
# unique          NaN           NaN           NaN           NaN           NaN
# top             NaN           NaN           NaN           NaN           NaN
# freq            NaN           NaN           NaN           NaN           NaN
# mean       81.86363    109.120685     17.167205     58.976332   1256.574729
# std        80.44949     93.718017     22.760801     37.061384   1223.301208
# min         3.00000      2.000000      0.571200      2.000000    100.000000
# 25%        22.00000     37.000000      3.000000     30.000000    500.000000
# 50%        58.00000     86.000000      8.000000     53.000000    800.000000
# 75%       114.00000    154.000000     21.000000     82.000000   1500.000000
# max       713.00000    948.000000    229.000000    290.000000  10000.000000
#
#                   O3          TEMP          PRES          DEWP          RAIN  \
# count   31815.000000  31815.000000  31815.000000  31815.000000  31815.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       56.240938     13.775611   1011.800385      3.241106      0.068235
# std        57.834314     11.369035     10.338869     13.667863      0.837489
# min         0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%         8.000000      3.400000   1003.300000     -8.000000      0.000000
# 50%        42.000000     14.800000   1011.200000      4.000000      0.000000
# 75%        82.000000     23.400000   1020.000000     15.700000      0.000000
# max       423.000000     40.500000   1042.000000     28.500000     46.400000
#
#            wd          WSPM       station
# count   31815  31815.000000         31815
# unique     16           NaN             1
# top        NE           NaN  Aotizhongxin
# freq     4581           NaN         31815
# mean      NaN      1.720471           NaN
# std       NaN      1.204240           NaN
# min       NaN      0.000000           NaN
# 25%       NaN      0.900000           NaN
# 50%       NaN      1.400000           NaN
# 75%       NaN      2.200000           NaN
# max       NaN     11.200000           NaN

# %% [markdown]
# untuk memperlihatkan data statistikal yang ada di dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31815 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       31815 non-null  int64
#  1   year     31815 non-null  int64
#  2   month    31815 non-null  int64
#  3   day      31815 non-null  int64
#  4   hour     31815 non-null  int64
#  5   PM2.5    31815 non-null  float64
#  6   PM10     31815 non-null  float64
#  7   SO2      31815 non-null  float64
#  8   NO2      31815 non-null  float64
#  9   CO       31815 non-null  float64
#  10  O3       31815 non-null  float64
#  11  TEMP     31815 non-null  float64
#  12  PRES     31815 non-null  float64
#  13  DEWP     31815 non-null  float64
#  14  RAIN     31815 non-null  float64
#  15  wd       31815 non-null  object
#  16  WSPM     31815 non-null  float64
#  17  station  31815 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.6+ MB

# %% [markdown]
# melihat type data

# %%
df['Date'] = df['year'].astype(str) + '-' + df['month'].astype(str) + '-' + df['day'].astype(str)
# Out:
# <ipython-input-356-897196dc897d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['year'].astype(str) + '-' + df['month'].astype(str) + '-' + df['day'].astype(str)

# %% [markdown]
# untuk membuat index tanggal

# %%
df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station       Date
# 0      -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin   2013-3-1
# 1      -1.1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin   2013-3-1
# 2      -1.1  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin   2013-3-1
# 3      -1.4  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin   2013-3-1
# 4      -2.0  1025.2 -19.5   0.0    N   2.0  Aotizhongxin   2013-3-1
# ...     ...     ...   ...   ...  ...   ...           ...        ...
# 35059  12.5  1013.5 -16.2   0.0   NW   2.4  Aotizhongxin  2017-2-28
# 35060  11.6  1013.6 -15.1   0.0  WNW   0.9  Aotizhongxin  2017-2-28
# 35061  10.8  1014.2 -13.3   0.0   NW   1.1  Aotizhongxin  2017-2-28
# 35062  10.5  1014.4 -12.9   0.0  NNW   1.2  Aotizhongxin  2017-2-28
# 35063   8.6  1014.1 -15.9   0.0  NNE   1.3  Aotizhongxin  2017-2-28
#
# [31815 rows x 19 columns]

# %% [markdown]
# memperlihatkan data Date sudah masuk ke dataframe

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index(['Date'])
# Out:
# <ipython-input-358-1efe410eb2b5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
#                No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO  \
# Date
# 2013-03-01      1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0
# 2013-03-01      2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0
# 2013-03-01      3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0
# 2013-03-01      4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0
# 2013-03-01      5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0
# ...           ...   ...    ...  ...   ...    ...   ...   ...   ...    ...
# 2017-02-28  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0
# 2017-02-28  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0
# 2017-02-28  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0
# 2017-02-28  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0
# 2017-02-28  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0
#
#               O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# Date
# 2013-03-01  77.0  -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 2013-03-01  77.0  -1.1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2013-03-01  73.0  -1.1  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 2013-03-01  72.0  -1.4  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 2013-03-01  72.0  -2.0  1025.2 -19.5   0.0    N   2.0  Aotizhongxin
# ...          ...   ...     ...   ...   ...  ...   ...           ...
# 2017-02-28  95.0  12.5  1013.5 -16.2   0.0   NW   2.4  Aotizhongxin
# 2017-02-28  81.0  11.6  1013.6 -15.1   0.0  WNW   0.9  Aotizhongxin
# 2017-02-28  58.0  10.8  1014.2 -13.3   0.0   NW   1.1  Aotizhongxin
# 2017-02-28  35.0  10.5  1014.4 -12.9   0.0  NNW   1.2  Aotizhongxin
# 2017-02-28  42.0   8.6  1014.1 -15.9   0.0  NNE   1.3  Aotizhongxin
#
# [31815 rows x 18 columns]

# %% [markdown]
# merubah date menjadi index agar bisa digunakan di timeseries

# %%
monthly_avg = df.groupby('month')['PM2.5','PM10','SO2','NO2','O3'].mean()
# Out:
# <ipython-input-359-73010c002fab>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   monthly_avg = df.groupby('month')['PM2.5','PM10','SO2','NO2','O3'].mean()

# %% [markdown]
# untuk menghitung rata-rata data

# %%
monthly_avg
# Out:
#             PM2.5        PM10        SO2        NO2         O3
# month
# 1       93.503752  114.948177  35.349204  66.659611  26.736283
# 2       83.207848  102.202020  31.022922  53.458819  44.012821
# 3      100.613010  152.487026  31.999964  63.858656  47.572606
# 4       75.201647  127.340904  16.131137  52.899579  65.300699
# 5       67.494173  114.649417  15.314457  48.019410  89.821506
# 6       69.755755   85.278580   8.038627  47.964885  95.629341
# 7       75.219323   85.114951   5.703808  47.868829  97.025035
# 8       55.060187   71.231049   4.357228  48.507378  85.557640
# 9       64.511714   87.490382   7.176647  59.286340  51.735217
# 10      96.320247  119.391130  10.569006  74.573246  26.566895
# 11      93.955397  118.530079  14.116349  70.916587  18.338450
# 12     110.896053  133.146930  26.976754  75.990351  19.942208

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# - Bagaimana perbedaan kualitas udara dilihat dari persepektif tiap bulan di daerah Aotizhongxin selama periode 2013-2017

# %%
plt.figure(figsize=(30, 12))
plt.plot(monthly_avg,label=['PM2.5','PM10','SO2','NO2','O3'])
plt.legend(loc="upper left")
plt.title("Perubahan kualitas air bedasarkan PM2.5,PM10,SO2,NO2 Dan O3")
plt.show()

# %% [markdown]
# untuk memvisualisasikan perubahan pada bulan awal sampai akhir

# %% [markdown]
# Dilihat dari hasil analisis data pada grafik tersebut menunjukan bahwa ketika awal dan diakhir tahun. kualitas udara kurang baik disebabkan beberapa faktor yaitu partikel 2.5, 10, sulfur dioksida dan nitrogen dioksida mengalami peningkatan yang cukup besar. sedangkan dari data o3 (ozon) membuktikan di pertengahan tahun mengalami peningkatan karena kualitas udara membaik

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# - Jenis Partikel mana yang mengalami perubahan paling banyak selama 2013 - 2017 di daerah Aotizhongxin

# %%
summary = df.describe()

# %% [markdown]
# untuk mengambil beberapa statistika data

# %%
features = ['PM2.5','PM10','SO2','NO2','O3']

# %% [markdown]
# membuat list feature untuk di visualisasikan

# %%
total_summary = []
for feat in features:
  total_summary.append(summary.loc["max",feat] - summary.loc["min",feat])

# %% [markdown]
# melakukan perulangan untuk mengetahui partikel mana yang memiliki perubahan terbanyak

# %%
total_summary
# Out:
# [710.0, 946.0, 228.4288, 288.0, 422.7858]

# %% [markdown]
# mengecek total perubahan

# %%
plt.bar(features, total_summary)
plt.title("Perbedaan jumlah partikel selama 4 tahun")
plt.show()

# %% [markdown]
# memvisualisakan perubahan terbanyak

# %% [markdown]
# dilihat dari hasil analisis pada grafik diatas partikel yang paling banyak berubah adalah partikel yg berukuran 10 mikrometer

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - conclution pertanyaan 2

# %% [markdown]
# *   conclusion  1 = air quality di awal dan diakhir bulan kurang baik dibandingkan di pertengahan tahun
#
# *  conclusion  2 = partikel yang paling tidak stabil dan mempengaruhi air quality adalah PM10
